# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Data generation

# %%
# generating data samples
x = np.linspace(-5.0, 5.0, 100)[:, np.newaxis]
y = 29 * x + 40 * np.random.rand(100,1)

# normalization of input data
x /= np.max(x)

plt.title('Data samples')
plt.scatter(x, y);

# %% [markdown]
# ## Sklearn Linear regression

# %%
sklearn_model = LinearRegression()
sklearn_model.fit(x, y)
y_hat_sklearn = sklearn_model.predict(x)

plt.title('Data samples')
plt.scatter(x, y)
plt.plot(x, y_hat_sklearn, color='r');

print('Sklearn MSE: ', mean_squared_error(y, y_hat_sklearn))
# Out:
# Sklearn MSE:  137.01379229008623

# %% [markdown]
# ## Implementation of Linear Regression from scratch

# %%
class MyLinearRegression:
    def __init__(self, weights_init='random', add_bias = True, learning_rate=1e-5, 
        num_iterations=2000000, verbose=False, max_error=1e-5):
        ''' Linear regression model using gradient descent 

        # Arguments
            weights_init: str
                weights initialization option ['random', 'zeros']
            add_bias: bool
                whether to add bias term 
            learning_rate: float
                learning rate value for gradient descent
            num_iterations: int 
                maximum number of iterations in gradient descent
            verbose: bool
                enabling verbose output
            max_error: float
                error tolerance term, after reaching which we stop gradient descent iterations
        '''

        self.num_iterations = num_iterations
        self.learning_rate = learning_rate
        self.weights_init = weights_init
        self.add_bias = add_bias
        self.verbose = verbose
        self.max_error = max_error
    
    def initialize_weights(self, n_features):
        ''' weights initialization function '''
        if self.weights_init == 'random':
            ################

            # YOUR CODE HERE
            weights = np.random.randn(n_features) * 0.01

            ################
        elif self.weights_init == 'zeros':
            ################

            # YOUR CODE HERE
            weights = np.zeros(n_features)

            ################
        else:
            raise NotImplementedError
        return weights

    def cost(self, target, pred):
        ''' calculate cost function 
        
            # Arguments:
                target: np.array
                    array of target floating point numbers 
                pred: np.array
                    array of predicted floating points numbers
        '''
        ################

        # YOUR CODE HERE
        squared_errors = (target - pred) ** 2
    
        # Calculate the mean of squared errors
        loss = np.mean(squared_errors)

        ################
        return loss

    def fit(self, x, y):
        if self.add_bias:
            ################

            # YOUR CODE HERE
            x = np.hstack((np.ones_like(x), x))

            ################

        self.weights = self.initialize_weights(x.shape[1])
        current_loss = None

        for i in range(self.num_iterations):
            ################

            # YOUR CODE HERE
            # step 1: calculate current_loss value
            predictions = np.dot(x, self.weights)
            current_loss = self.cost(y, predictions)

            # step 2: calculate gradient value
            gradient = self.calculate_gradient(x, y, predictions)

            # step 3: update weights using learning rate and gradient value
            self.weights -= self.learning_rate * gradient

            # step 4: calculate new_loss value
            predictions = np.dot(x, self.weights)
            new_loss = self.cost(y, predictions)

            # step 5: if new_loss and current_loss difference is greater than max_error -> break;
            #         if iteration is greater than max_iterations -> break
            loss_difference = abs(new_loss - current_loss)
            if loss_difference < self.max_error or i >= self.num_iterations:
                break
            ################
    
    def calculate_gradient(self, x, y, predictions):
        """
        Calculate the gradient of the cost function with respect to the model's weights.

        Parameters:
        x (numpy array): Array of input features.
        y (numpy array): Array of true target values.
        predictions (numpy array): Array of predicted target values.

        Returns:
        numpy array: Array of gradients for the weights.
        """
        m = len(y)  # Number of training examples

        # Calculate the gradient for the intercept (theta_0)
        gradient_theta_0 = (1 / m) * np.sum(predictions - y)

        # Calculate the gradient for the slope (theta_1)
        #gradient_theta_1 = (1 / m) * np.sum((predictions - y) * x)
        gradient_theta_1 = (1 / m) * np.sum(np.dot((predictions - y), x))

        # Combine the gradients into an array
        gradients = np.array([gradient_theta_0, gradient_theta_1])

        return gradients
    
    def predict(self, x):
        ''' prediction function '''
        ################

        # YOUR CODE HERE
        if self.add_bias:
            x = np.hstack((np.ones_like(x), x))
        
        y_hat = np.dot(x, self.weights)

        ################
        return y_hat

# %%
my_model = MyLinearRegression()
my_model.fit(x, y)
y_hat = my_model.predict(x)

plt.title('Data samples')
plt.scatter(x, y)
plt.plot(x, y_hat, color='r');

print('My MSE: ', mean_squared_error(y, y_hat))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Playground\ML\src\pract_01\linear_regression.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> my_model = MyLinearRegression()
# ----> <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> my_model.fit(x, y)
#       <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> y_hat = my_model.predict(x)
#       <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> plt.title('Data samples')
#
# d:\Playground\ML\src\pract_01\linear_regression.ipynb Cell 8 line 8
#      <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=85'>86</a> current_loss = self.cost(y, predictions)
#      <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=87'>88</a> # step 2: calculate gradient value
# ---> <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=88'>89</a> gradient = self.calculate_gradient(x, y, predictions)
#      <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=90'>91</a> # step 3: update weights using learning rate and gradient value
#      <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=91'>92</a> self.weights -= self.learning_rate * gradient
#
# d:\Playground\ML\src\pract_01\linear_regression.ipynb Cell 8 line 1
#     <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=119'>120</a> gradient_theta_0 = (1 / m) * np.sum(predictions - y)
#     <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=121'>122</a> # Calculate the gradient for the slope (theta_1)
#     <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=122'>123</a> #gradient_theta_1 = (1 / m) * np.sum((predictions - y) * x)
# --> <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=123'>124</a> gradient_theta_1 = (1 / m) * np.sum(np.dot((predictions - y), x))
#     <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=125'>126</a> # Combine the gradients into an array
#     <a href='vscode-notebook-cell:/d%3A/Playground/ML/src/pract_01/linear_regression.ipynb#X10sZmlsZQ%3D%3D?line=126'>127</a> gradients = np.array([gradient_theta_0, gradient_theta_1])
#
# ValueError: shapes (100,2) and (100,2) not aligned: 2 (dim 1) != 100 (dim 0)
